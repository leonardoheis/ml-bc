# %%
import sys
print(f"Python executable: {sys.executable}")
print(f"Python version: {sys.version}")
# %pip install -r requirements.txt
# Out:
# Python executable: c:\Users\leona\source\repos\ml-bc\.venv\Scripts\python.exe
# Python version: 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)]
# Requirement already satisfied: mlflow in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from -r requirements.txt (line 1)) (3.8.1)
# Requirement already satisfied: scikit-learn in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from -r requirements.txt (line 2)) (1.7.2)
# Requirement already satisfied: pandas in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from -r requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: Flask<4 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (7.1.0)
# Requirement already satisfied: matplotlib<4 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (3.10.8)
# Requirement already satisfied: numpy<3 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (2.2.6)
# Requirement already satisfied: cryptography<47,>=43.0.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (46.0.3)
# Requirement already satisfied: mlflow-skinny==3.8.1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (3.8.1)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (22.0.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (1.17.2)
# Requirement already satisfied: waitress<4 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: mlflow-tracing==3.8.1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (3.8.1)
# Requirement already satisfied: graphene<4 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (3.4.3)
# Requirement already satisfied: Flask-CORS<7 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: huey<3,>=2.5.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (2.5.5)
# Requirement already satisfied: scipy<2 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (2.0.45)
# Requirement already satisfied: cloudpickle<4 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (6.2.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (3.1.46)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (1.39.1)
# Requirement already satisfied: fastapi<1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (0.128.0)
# Requirement already satisfied: pydantic<3,>=2.0.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (2.12.5)
# Requirement already satisfied: click<9,>=7.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (8.3.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (0.76.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (1.39.1)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (6.33.2)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: packaging<26 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: uvicorn<1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (0.40.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (0.5.5)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (2.32.5)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (1.39.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from scikit-learn->-r requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from scikit-learn->-r requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from pandas->-r requirements.txt (line 3)) (2025.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from pandas->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from pandas->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: Mako in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from alembic!=1.10.0,<2->mlflow->-r requirements.txt (line 1)) (1.3.10)
# Requirement already satisfied: tomli in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from alembic!=1.10.0,<2->mlflow->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from cryptography<47,>=43.0.0->mlflow->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pywin32>=304 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from docker<8,>=4.0.0->mlflow->-r requirements.txt (line 1)) (311)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from docker<8,>=4.0.0->mlflow->-r requirements.txt (line 1)) (2.6.2)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from Flask<4->mlflow->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from Flask<4->mlflow->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from Flask<4->mlflow->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from graphene<4->mlflow->-r requirements.txt (line 1)) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from graphene<4->mlflow->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from matplotlib<4->mlflow->-r requirements.txt (line 1)) (1.4.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from matplotlib<4->mlflow->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from matplotlib<4->mlflow->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: pillow>=8 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from matplotlib<4->mlflow->-r requirements.txt (line 1)) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from matplotlib<4->mlflow->-r requirements.txt (line 1)) (3.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from matplotlib<4->mlflow->-r requirements.txt (line 1)) (4.61.1)
# Requirement already satisfied: six>=1.5 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: greenlet>=1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: pycparser in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow->-r requirements.txt (line 1)) (2.23)
# Requirement already satisfied: colorama in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from click<9,>=7.0->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (2.45.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from fastapi<1->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from fastapi<1->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from Jinja2>=3.0->Flask<4->mlflow->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (0.60b1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (2026.1.4)
# Requirement already satisfied: h11>=0.8 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from uvicorn<1->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (4.9.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (4.12.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\leona\source\repos\ml-bc\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow->-r requirements.txt (line 1)) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# # mlflow - Experiment Tracking: Air Quality Classification

# %% [markdown]
# Our goal in this notebook is to demonstrate the power of **experiment tracking**  using **MLflow**—an open-source platform designed to simplify the management of machine learning workflows. In the world of machine learning, tracking experiments is crucial for ensuring transparency, reproducibility, and effective model management. MLflow allows us to log not only parameters, metrics, and models but also track and compare multiple experiments over time. This makes it easier to optimize model performance, fine-tune hyperparameters, and maintain a history of all experiments for future reference.
#
# In this notebook, we will use MLflow to track and manage the development of a classification model aimed at predicting **air quality**. Our dataset contains various environmental features, including temperature, humidity, pollutant levels (such as PM2.5, PM10, NO2, SO2, CO), and factors like proximity to industrial areas and population density. By building a predictive model, we aim to classify air quality into categories like "Good" , "Moderate" or "Hazardous" based on these features. Throughout the process, we will log every aspect of the model training and evaluation, from hyperparameters to performance metrics, ensuring we have a clear and organized record of our work with MLflow.

# %%
# import Libraries
import mlflow
import mlflow.sklearn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Load the dataset from a CSV file
df = pd.read_csv('air_quality.csv')  # Replace with the path to your CSV file

# Check the first few rows of the dataset to understand its structure
print(df.head())

# Feature columns and target variable
X = df.drop('Air Quality', axis=1)
y = df['Air Quality']
# Out:
#    Temperature  Humidity  PM2.5  PM10   NO2   SO2    CO  \
# 0         29.8      59.1    5.2  17.9  18.9   9.2  1.72
# 1         28.3      75.6    2.3  12.2  30.8   9.7  1.64
# 2         23.1      74.7   26.7  33.8  24.4  12.6  1.63
# 3         27.1      39.1    6.1   6.3  13.5   5.3  1.15
# 4         26.5      70.7    6.9  16.0  21.9   5.6  1.01
#
#    Proximity_to_Industrial_Areas  Population_Density Air Quality
# 0                            6.3                 319    Moderate
# 1                            6.0                 611    Moderate
# 2                            5.2                 619    Moderate
# 3                           11.1                 551        Good
# 4                           12.7                 303        Good

# %%
# Encode the target variable (Air Quality) using Label Encoding
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split the dataset into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# %%
# Define model hyperparameters
params = {
    "solver": "lbfgs",
    "max_iter": 1000,
    "random_state": 44,
}

# Train the model
lr = LogisticRegression(**params)
lr.fit(X_train, y_train)

# Predict on the test set
y_pred = lr.predict(X_test)

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average="weighted")
recall = recall_score(y_test, y_pred, average="weighted")
f1 = f1_score(y_test, y_pred, average="weighted")

print(accuracy, precision, recall, f1)
# Out:
# 0.948 0.948699773521202 0.948 0.9479213062383529

# %% [markdown]
# ### Experiment Tracking

# %% [markdown]
# Before we begin training our model, the first thing we need to do is define and set an experiment in MLflow.
#
# - **Experiment:** In MLflow, an experiment acts as a container that holds all the runs (individual model training sessions) related to a specific task or project.
# - **Run:** A run represents a single execution of a machine learning model, including its parameters, metrics, and results. Each time you train a model, MLflow logs this as a new run.

# %% [markdown]
# By organizing our runs under a specific experiment, we can easily track, compare, and organize all the different model runs in one place. This structure allows us to quickly evaluate the impact of different configurations, hyperparameters, or model versions over time

# %% [markdown]
# - The **MLflow Tracking Server (UI)** is running on http://127.0.0.1:5000/.
# By setting `mlflow.set_tracking_uri(remote_server_uri)`, you're telling MLflow to track experiments and logs on that server instead of using the default local storage.
# - If you don't explicitly set a remote tracking URI with mlflow.set_tracking_uri(), MLflow will log the experiments and their associated metrics and models locally in the **./mlruns** directory.
# This folder is where MLflow stores all the experiment data.
#
#     - **Experiment Folder:** Each experiment is assigned a unique experiment ID and stored in a subfolder within mlruns.
#     - **Run Folder:** Within each experiment, every individual model training session is represented by a run, which is given a unique run ID. Each run is stored in its own folder under the experiment directory.

# %%
# remote_server_uri = "http://127.0.0.2:5000/"
# mlflow.set_tracking_uri(remote_server_uri)
# print(mlflow.tracking.get_tracking_uri())

# %%
mlflow.set_tracking_uri("file:./mlruns")

# %%
# Set the experiment name
mlflow.set_experiment('Air_Quality_Experiment')
# Out:
# c:\Users\leona\source\repos\ml-bc\.venv\lib\site-packages\mlflow\tracking\_tracking_service\utils.py:178: FutureWarning: The filesystem tracking backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance. For migrating existing data, https://github.com/mlflow/mlflow-export-import can be used.
#   return FileStore(store_uri, store_uri)
# 2026/01/05 14:00:59 INFO mlflow.tracking.fluent: Experiment with name 'Air_Quality_Experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location=('file:///c:/Users/leona/source/repos/ml-bc/Day '
#  '1/lesson-3-mlflow/mlruns/416342201996408782'), creation_time=1767632459011, experiment_id='416342201996408782', last_update_time=1767632459011, lifecycle_stage='active', name='Air_Quality_Experiment', tags={}>

# %% [markdown]
# Once the experiment is set up in MLflow, we can start tracking various aspects of our model, such as **parameters, metrics, and the model itself**. These are logged during each run, allowing us to monitor and evaluate different model configurations over time. Here’s how we can log each of these elements:
#
# - `set_tag:` Used to set metadata for the run, such as specifying the model type, dataset name, or experiment category. This helps in organizing and filtering runs.
# - `log_param:` This function is used to log parameters that are part of the model, such as hyperparameters (e.g., the number of iterations, learning rate, etc.).
# - `log_metric:` This function logs performance metrics, such as accuracy, precision, recall, or loss, which are useful for evaluating how well the model is performing.
# - `log_model:` This function is used to log the trained machine learning model, so it can be saved and retrieved for future use or deployment.

# %% [markdown]
# #### Logging parameters and Model

# %%
# Start MLflow run
with mlflow.start_run():

    # Set experiment tags
    mlflow.set_tag("model_type", "LogisticRegression")
    mlflow.set_tag("experiment_name", "Air Quality Classification")

    # Log model parameters
    for param, value in params.items():
        mlflow.log_param(param, value)

    # Log evaluation metrics
    mlflow.log_metric("accuracy", accuracy)
    mlflow.log_metric("precision", precision)
    mlflow.log_metric("recall", recall)
    mlflow.log_metric("f1_score", f1)

    # Log trained model
    mlflow.sklearn.log_model(lr, "model")

    # Print run details
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(f"Model saved in run: {mlflow.active_run().info.run_id}")
# Out:
# 2026/01/05 14:01:03 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Accuracy: 0.9480
# Precision: 0.9487
# Recall: 0.9480
# F1 Score: 0.9479
# Model saved in run: 0e72c97e06a049d19719551ecbbc61ad

# %%
# Get the experiment ID
experiment_name = 'Air_Quality_Experiment'
experiment = mlflow.get_experiment_by_name(experiment_name)
experiment_id = experiment.experiment_id if experiment else None

if experiment_id:
    # Get the list of runs in the experiment
    runs = mlflow.search_runs(experiment_ids=experiment_id)

    # Print run details
    print(runs.columns)

    # Access metrics.accuracy correctly
    for index, row in runs.iterrows():
        print(f"Run ID: {row['run_id']}, Status: {row['status']}, Accuracy: {row['metrics.accuracy']}")
else:
    print(f"Experiment with name '{experiment_name}' not found.")
# Out:
# Index(['run_id', 'experiment_id', 'status', 'artifact_uri', 'start_time',
#        'end_time', 'metrics.precision', 'metrics.accuracy', 'metrics.f1_score',
#        'metrics.recall', 'params.max_iter', 'params.solver',
#        'params.random_state', 'tags.experiment_name', 'tags.mlflow.user',
#        'tags.mlflow.source.type', 'tags.model_type', 'tags.mlflow.runName',
#        'tags.mlflow.source.name'],
#       dtype='object')
# Run ID: 0e72c97e06a049d19719551ecbbc61ad, Status: FINISHED, Accuracy: 0.948

# %% [markdown]
# #### Loading the Model for Prediciton

# %% [markdown]
# After a model is logged in MLflow, it can be loaded again by specifying the **run ID**. The model is retrieved using `mlflow.sklearn.load_model()`, which takes the run ID to locate and load the specific model from the logged experiment. This allows you to access and use the model at any time after it has been logged, facilitating its reuse in future predictions or analysis.

# %%
# Logged model in MLFlow
mlflow_run_id = '0e72c97e06a049d19719551ecbbc61ad' #choose the runid for the model you want to load
logged_model_path = f"runs:/{mlflow_run_id}/model"

# Load model as a sklearn model
loaded_model = mlflow.sklearn.load_model(logged_model_path)

# %%
y_pred = loaded_model.predict(X_test)

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.948
